# %% [markdown]
# 1. Practice :
#
#
# * get the txt from sample.txt and count the folowing
# * number of lines
# * njmber of words
# * number of characters
# * and save it to the counter of string.txt file

# %%
from functools import reduce
with open ("./sample_data/sample.txt","r") as file:
  string=file.readlines()
  total_lines=len(string)
  print(string)
  print(total_lines)

  #word
  number_words=list(map(lambda x: len(x.split()),string))
  print(number_words)
  total_number_words=reduce(lambda x,y: x+y,number_words)
  print(total_number_words)


  #character
  #clean remoce lewline
  string=list(map(str.strip,string))
  print(string)
  #remove sapace
  string=list(map(lambda x:x.replace(" ",""),string))
  number_char=list(map(lambda x: len(x),string))
  print(string)
  print(number_char)
  total_number_char=reduce(lambda x,y: x+y,number_char)
  print(total_number_char)

with open ("./sample_data/counter_of_string.txt","w") as file:
  file.write(f"total line:{total_lines}\ntotal num of word:{total_number_words}\ntotal number of charcter:{total_number_char}")
# Out:
# ['hello\n', 'what is your name\n', 'how are you']
# 3
# [1, 4, 3]
# 8
# ['hello', 'what is your name', 'how are you']
# ['hello', 'whatisyourname', 'howareyou']
# [5, 14, 9]
# 28

# %%
from functools import reduce
with open("./sample_data/sample.txt","r") as file:
  #total line
  list_string=file.readlines()
  print(list_string)
  total_line=len(list_string)
  print(total_line)

  #total word
  words=list(map(lambda x: len(x.split()),list_string))
  print(words)
  total_number_words=reduce(lambda x,y:x+y,words)
  print(total_number_words)

  #total character
  #remove lewline
  list_string=list(map(str.strip,list_string))
  print(list_string)
  #remove space
  list_string=list(map(lambda x:x.replace(" ",""),list_string))
  print(list_string)
  #count
  characters=list(map(lambda x: len(x),list_string))
  print(characters)
  total_number_char=reduce(lambda x,y: x+y,characters)
  print(total_number_char)

#new file create
with open("./sample_data/counter_of_string.txt","w") as file:
 file.write(f"Total number of lines:{total_line}\nTotal number of words:{total_number_words}\nTotal number of character:{total_number_char}")
# Out:
# ['hello\n', 'what is your name\n', 'how are you']
# 3
# [1, 4, 3]
# 8
# ['hello', 'what is your name', 'how are you']
# ['hello', 'whatisyourname', 'howareyou']
# [5, 14, 9]
# 28

# %% [markdown]
# 2.
# * Create a text file named emails.txt containing multiple email addresses, some in uppercase and some repeated.
# * Write a Python program to clean the data by converting all emails to lowercase, removing duplicates, sorting them alphabetically, and saving the cleaned list to a new file named unique_emails.txt.

# %%
raw_mail=[
    "User.Name@gmail.com\n",
    "example@yahoo.com\n",
    "USER.NAME@GMAIL.COM\n",
    "abc@company.com\n",
    "example@yahoo.com\n",
    "INFO@domain.org\n",
    "abc@company.com\n"
]
with open("./sample_data/emails.txt","w") as file:
  new=file.writelines(raw_mail)

with open("./sample_data/emails.txt","r") as file:
  newmail=file.readlines()

  upper1=list(map(lambda x: x.lower(),newmail))
  print(upper1)
  # removing duplicates,
  duplicate1= list(set(upper1))
  print(duplicate1)
  #sort
  # SORT (lambda used)
  sorted1 = sorted(duplicate1)
  print(sorted1)

with open("./sample_data/unique_emails.txt","w") as file:
  # file.write(f"Mail list:{sorted1}")
  file.write("".join(sorted1))
# Out:
# ['user.name@gmail.com\n', 'example@yahoo.com\n', 'user.name@gmail.com\n', 'abc@company.com\n', 'example@yahoo.com\n', 'info@domain.org\n', 'abc@company.com\n']
# ['abc@company.com\n', 'info@domain.org\n', 'example@yahoo.com\n', 'user.name@gmail.com\n']
# ['abc@company.com\n', 'example@yahoo.com\n', 'info@domain.org\n', 'user.name@gmail.com\n']

# %% [markdown]
# 3.Create a text file named names.txt containing a list of names.
# Some names may have extra spaces, inconsistent capitalization (like “aLiCe” or “ bob ”), or appear more than once.
# * Write a Python program to clean the data by:
# 1.  Removing extra spaces.
# 2.  Converting all names so that only the first letter is capitalized.
# 3.  Removing duplicate names.
# 4. Sorting the names alphabetically.
# * Finally, save the cleaned list into a new file named clean_names.txt.

# %%
raw_names={
    "  aLiCe \n",
    " bob \n",
    "ALICE\n",
    "charlie\n",
    "  bOb\n",
    "David\n",
    "charlie\n"
}
with open("./sample_data/names.txt","w") as file:
  raw=file.writelines(raw_names)

with open("./sample_data/names.txt","r") as file:
  garbez=file.readlines()
  # print(file.tell())
  #remove extra space
  w_space=list(map(lambda x:x.strip().capitalize(),garbez))
  w_space2=list(set(w_space))
  final_names=sorted(w_space2)
  print(final_names)
# Out:
# ['Alice', 'Bob', 'Charlie', 'David']

# %% [markdown]
# 4.Write a Python program that creates a list of 5 numbers.
# Ask the user for an index number and print the value at that index.
# If the index is out of range, handle the exception and print "Invalid index!".

# %%
numbers = [10, 25, 45, 70, 99]

try:
    index = int(input("Enter an index number (0 to 4): "))
    print(f"Value at index {index}: {numbers[index]}")
except IndexError:
    print("Invalid index!")
except ValueError:
    print("Invalid input! Please enter an integer.")
# Out:
# Enter an index number (0 to 4): 5
# Invalid index!

# %% [markdown]
# Problem 1 : Common Friends (Set Operations)
# Problem:
#  Given two sets of friends from two people, find the mutual friends, unique friends of each, and the total number of unique friends.

# %%
friend1 = input("Enter friends for person 1: ").split()
friend2 = input("Enter friends for person 2: ").split()
#find the mutual friends
mutual=set(filter(lambda x: x in friend2,friend1))
print(mutual)
# unique friends of each
unique1=set(filter(lambda x: x not in friend2,friend1))
print(f"unique1:{unique}")
unique2=set(filter(lambda x: x not in friend1,friend2))
print(f"unique2:{unique2}")
#total_unique
total_unique = len(set(friend1 + friend2))
print(f"Total unique friends: {total_unique}")
# Out:
# Enter friends for person 1: Rahim Karim Ajme Pro Toma
# Enter friends for person 2: Ajme Toma Mina Raje Mi
# {'Ajme', 'Toma'}
# unique1:{'ami', 'he', 'tmi'}
# unique2:{'Raje', 'Mina', 'Mi'}
# Total unique friends: 8

# %% [markdown]
# Problem 2: Sort Students by Marks (Tuple + Dictionary)
# Problem:
#  You are given a list of tuples — each containing a student’s name and mark.
#  Sort them in descending order of marks and print the top 3 scorers.

# %%
student_info=[
    ("Rahim", 85),
    ("Karim", 92),
    ("Sakib", 78),
    ("Jamal", 95),
    ("Rafiq", 88),
    ("Nadim", 91)
]
sorted_students = sorted(student_info, key=lambda x: x[1], reverse=True)
students_dict = dict(sorted_students)
print(students_dict)
for name, mark in list(students_dict.items())[:3]:
    print(f"{name} - {mark}")
# Out:
# {'Jamal': 95, 'Karim': 92, 'Nadim': 91, 'Rafiq': 88, 'Rahim': 85, 'Sakib': 78}
# Jamal - 95
# Karim - 92
# Nadim - 91

# %% [markdown]
# Problem 3: Word Length Filter (Lambda + Filter)
# Problem:
#  Given a list of words, use filter() and lambda to return only words whose length is greater than 4.

# %%
words = ["apple", "bat", "banana", "cat", "mango", "egg", "python"]
filtered_words = list(filter(lambda x: len(x) > 4, words))

print(filtered_words)
# Out:
# ['apple', 'banana', 'mango', 'python']

# %% [markdown]
# Problem 4: Square of Even Numbers (Map + Filter + Lambda)
# Problem:
#  Write a one-line Python expression using map(), filter(), and lambda that takes a list of integers and returns the squares of even numbers only.

# %%
lst=[1,3,4,5,6,7,7,8]
squre_even=list(map(lambda x:x**2,filter(lambda x:x%2==0,lst)))
print(squre_even)
# Out:
# [16, 36, 64]

# %% [markdown]
# Problem 5: Write and Read a File
# Problem:
#  Write a Python program to:
# Create a text file named data.txt
#
#
# Write “Learning Python is fun!” into it.
#
#
# Read the file and print its content.

# %%
with open("./sample_data/data.txt","w") as file:
  file.write("Learning Python is fun!")
with open("./sample_data/data.txt","r") as file:
  file1=file.read()
print(file1)
# Out:
# Learning Python is fun!

# %% [markdown]
#  Problem 6: Count Lines in a File
# Problem:
#  Write a Python program to count how many lines are in a text file named story.txt.
#  If the file does not exist, handle the exception and print an error message, otherwise read the text file ( test it with both conditions ). Print a message finally.

# %%
file_name="story.txt"
try:
  with open("./file_name","r") as file:
    lines=file.readlines()
    line_count=len(lines)
    print(f"Success! The file '{file_name}' has {line_count} lines.")
except FileNotFoundError:
  print(f"Error: The file '{file_name}' was not found. Please create it first.")
finally:
    print("File processing attempt completed.")
# Out:
# Error: The file 'story.txt' was not found. Please create it first.
# File processing attempt completed.
